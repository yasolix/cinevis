# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
# %matplotlib inline

# %%
asl = pd.read_csv('/home/yt/cinevis/data/AverageShotLengthData.csv',sep='\t')
asl.count()
# Out:
# Title                11005
# Alternative Title      743
# Year                 11001
# Director             10990
# ASL                  11003
# Country               9637
# Scope                 1995
# Cinematographer      10034
# Editor                9673
# Studio                4376
# dtype: int64

# %%
asl.tail(30)
# Out:
#                              Title          Alternative Title    Year  \
# 10975     Zakroishchik iz Torzhka   Tailor from Torzhok, The   1925.0
# 10976                    Zandalee                         NaN  1991.0
# 10977  Zathura: A Space Adventure                         NaN  2005.0
# 10978                    Zatoichi                         NaN  2003.0
# 10979         Ze soboty na nedeli    From Saturday to Sunday   1931.0
# 10980                   Zebrahead                         NaN  1992.0
# 10981      Zed and Two Noughts, A                         NaN  1985.0
# 10982                    Zeppelin                         NaN  1971.0
# 10983       Zerbrochene Krug, Der                         NaN  1937.0
# 10984                     Zerkalo                     Mirror   1974.0
# 10985                 Zero Effect                         NaN  1997.0
# 10986              Zero Tolerance                         NaN  1994.0
# ...

# %%
cammov = pd.read_csv('/home/yt/cinevis/data/CameraMovementData.csv',sep='\t')
cammov.count()
# Out:
# TITLE         122
# YEAR          122
# Director      122
# Pan           122
# Tilt          122
# PanwTilt      122
# Track         122
# TrwPan        122
# TrwPanTilt    111
# Crane          92
# Zoom          102
# Total         122
# dtype: int64

# %%
cammov
# Out:
#                                    TITLE  YEAR                  Director  Pan  \
# 0            10 Things I Hate About You   1999              Junger, Gil    12
# 1             Almost Perfect Affair, An   1979          Michael Ritchie    41
# 2                Amityville horror, The   1979         Stuart Rosenberg    43
# 3                        Angela's Ashes   1999             Parker, Alan    21
# 4                            Annie Hall   1977             Allen, Woody    35
# 5                      Another Thin Man   1939           Van Dyke, W.S.    41
# 6          Arsenal Stadium Mystery, The   1939       Dickinson, Thorold     4
# 7                         At the Circus   1939          Bussell, Edward    43
# 8                           Back Street   1941        Stevenson, Robert    13
# 9             Behemoth, The Sea Monster   1959           Lourié, Eugene    20
# 10                              Ben-Hur   1959           Wyler, William    24
# ...

# %%
shotscale = pd.read_csv('/home/yt/cinevis/data/ShotScaleData.csv',sep='\t')
shotscale.count()
# Out:
# Title       388
# Year        386
# Director    372
# ASL         388
# RA          388
# POV         388
# INS         388
# COUNTRY     387
# ITITLE      321
# BCU         387
# CU          388
# MCU         388
# MS          388
# MLS         388
# LS          388
# VLS         388
# dtype: int64

# %%
shotscale
# Out:
#                               Title    Year                    Director   ASL  \
# 0       10 Things I Hate About You   1999.0                Junger, Gil    6.7
# 1    Adventures of Robin Hood, The   1938.0  Curtiz, M. & Keighley, W.    5.0
# 2          Affairs of Anatole, The   1921.0          DeMille, Cecil B.    8.0
# 3                 Alexander Nevsky   1938.0         Eisenstein, Sergei    7.0
# 4                        Alley Cat   1929.0            Steinhoff, Hans    6.0
# 5        Almost Perfect Affair, An   1979.0            Michael Ritchie    4.2
# 6             American Tragedy, An   1931.0       Sternberg, Josef von   13.0
# 7           Amityville Horror, The   1979.0           Stuart Rosenberg    5.5
# 8                   Angela's Ashes   1999.0               Parker, Alan    3.9
# 9                            Angst   1928.0            Steinhoff, Hans    5.5
# 10                         Annelie   1941.0            Baky, Josef von   12.0
# ...

# %%
shotscale.columns
# Out:
# Index([u'Title', u'Year', u'Director', u'ASL', u'RA', u'POV', u'INS',
#        u'COUNTRY', u'ITITLE', u'BCU', u'CU', u'MCU', u'MS', u'MLS', u'LS',
#        u'VLS'],
#       dtype='object')

# %%
cammov.columns
# Out:
# Index([u'TITLE', u'YEAR', u'Director', u'Pan', u'Tilt', u'PanwTilt', u'Track',
#        u'TrwPan', u'TrwPanTilt', u'Crane', u'Zoom', u'Total'],
#       dtype='object')

# %%
asl.columns
# Out:
# Index([u'Title', u'Alternative Title', u'Year', u'Director', u'ASL',
#        u'Country', u'Scope', u'Cinematographer', u'Editor', u'Studio'],
#       dtype='object')

# %%
 asl.ASL.describe()
# Out:
# count    11003.000000
# mean         7.737975
# std         12.764685
# min          0.000000
# 25%          4.510000
# 50%          6.400000
# 75%          8.905000
# max       1000.000000
# Name: ASL, dtype: float64

# %%
asl.describe()
# Out:
#                Year           ASL
# count  11001.000000  11003.000000
# mean    1978.335606      7.737975
# std       32.586225     12.764685
# min       14.000000      0.000000
# 25%     1957.000000      4.510000
# 50%     1988.000000      6.400000
# 75%     2000.000000      8.905000
# max     2014.000000   1000.000000

# %%
asl['Year'].apply(lambda x: int(x) if pd.notnull(x)  else 1800)
# Out:
# 0        2003
# 1        2008
# 2        2007
# 3        2009
# 4        1972
# 5        1987
# 6        2012
# 7        2009
# 8        1979
# 9        1999
# 10       2011
# 11       2008
# 12       1996
# 13       2000
# 14       2000
# 15       2006
# 16       2011
# 17       2010
# 18       2004
# 19       1946
# 20       2005
# 21       1999
# 22       2001
# 23       2006
# 24       2009
# 25       1914
# 26       1979
# 27       1994
# 28       2006
# 29       2003
#          ...
# 10975    1925
# 10976    1991
# 10977    2005
# 10978    2003
# 10979    1931
# 10980    1992
# 10981    1985
# 10982    1971
# 10983    1937
# 10984    1974
# 10985    1997
# 10986    1994
# 10987    1997
# 10988    1938
# 10989    1913
# 10990    2007
# 10991    2005
# 10992    2009
# 10993    2007
# 10994    1933
# 10995    2011
# 10996    2001
# 10997    2006
# 10998    1981
# 10999    2000
# 11000    1964
# 11001    1979
# 11002    1925
# 11003    2006
# 11004    1912
# ...

# %%
asl[asl['Year'] < 1800]
# Out:
#                        Title Alternative Title    Year  \
# 622   Astonished Heart, The                NaN    14.0
# 4513        Hindenburg, The                NaN  1075.0
#
#                         Director    ASL Country Scope   Cinematographer  \
# 622   Fisher, T. & Darnborough,   14.10    BRI    NaN      Asher, Jack
# 4513               Wise, Robert    5.94    USA     s   Surtees, Robert
#
#               Editor Studio
# 622    Sagovsky, V.     GAI
# 4513  Cambern, Donn     UNI

# %%
asl[asl['ASL'] > 200]
# Out:
#                                        Title Alternative Title    Year  \
# 31                               20 Fingers                NaN  2004.0
# 1722                         Carry On Girls                NaN  1973.0
# 3472  First $20 Million is the Hardest, The                NaN  2002.0
# 8251                                   Rope                NaN  1948.0
#
#                 Director     ASL Country Scope     Cinematographer  \
# 31        Akbari, Mania    475.7    IRA    NaN      Aslani, Toraj
# 1722     Thomas, Gerald    448.0    BRI    NaN         Hume, Alan
# 3472      Jackson, Mick    229.0     NaN   NaN        Garcia, Ron
# 8251  Hitchcock, Alfred   1000.0    USA    NaN  Valentine & Skall
#
#               Editor Studio
# 31               NaN    NaN
# 1722  Roome, Alfred     NaN
# 3472    Brochu, Don     NaN
# 8251    Ziegler, W.     NaN

# %%
meanasl= asl.groupby('Year').ASL.mean()

# %%
newasl = asl[asl['Year'] > 1800]

# %%
newasl[newasl['ASL'] > 150]
# Out:
#                                        Title Alternative Title    Year  \
# 31                               20 Fingers                NaN  2004.0
# 1722                         Carry On Girls                NaN  1973.0
# 3472  First $20 Million is the Hardest, The                NaN  2002.0
# 7592                                   Play                NaN  2011.0
# 8251                                   Rope                NaN  1948.0
#
#                 Director      ASL Country Scope             Cinematographer  \
# 31        Akbari, Mania    475.70    IRA    NaN              Aslani, Toraj
# 1722     Thomas, Gerald    448.00    BRI    NaN                 Hume, Alan
# 3472      Jackson, Mick    229.00     NaN   NaN                Garcia, Ron
# 7592     Östlund, ruben    154.97    SWE    NaN  Dybwad, Marius & Brandrud
# 8251  Hitchcock, Alfred   1000.00    USA    NaN          Valentine & Skall
#
#                             Editor Studio
# 31                             NaN    NaN
# ...

# %%
newasl.loc[8251,'ASL'] = 15
# Out:
# /home/yt/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
meannewasl= newasl.groupby('Year').ASL.mean()

# %%
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
SMALL_SIZE = 8
MEDIUM_SIZE = 30
BIGGER_SIZE = 12

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

def displayASL(asl):
    plt.figure(figsize=(20,20))
    plt.axis([1905,1990,0,30])
    plt.grid(True)
    plt.scatter(asl['Year'],asl['ASL'])

plt.figure(figsize=(20,20))
plt.axis([1915,2017,0,30])
plt.grid(True)
plt.scatter(newasl['Year'],newasl['ASL'])
plt.plot(meannewasl,'r',linewidth=4.0)
plt.xlabel('Years')
plt.ylabel('Average Shot Length (seconds)')
plt.title('ASL of Movies in Years ')
plt.show()

# %%
directorwork = asl.groupby('Director').count()
directorwork.max()
directorwork.Title.plot(kind='bar')

# %%
directorwork[ directorwork.Title > 30]
# Out:
#                     Title  Alternative Title  Year  ASL  Country  Scope  \
# Director
# Ford, John             36                  0    36   36       35      4
# Hitchcock, Alfred      53                  2    53   53       53      0
# Lang, Fritz            38                  8    38   38       38      0
# Thomas, Gerald         34                  3    34   34       34      0
#
#                     Cinematographer  Editor  Studio
# Director
# Ford, John                       29      29      25
# Hitchcock, Alfred                44      38      13
# Lang, Fritz                       7       6       6
# Thomas, Gerald                   33      33       5

# %%
directorwork[ directorwork.Title == 53]
# Out:
#                     Title  Alternative Title  Year  ASL  Country  Scope  \
# Director
# Hitchcock, Alfred      53                  2    53   53       53      0
#
#                     Cinematographer  Editor  Studio
# Director
# Hitchcock, Alfred                44      38      13

# %%
ford = asl[ asl['Director'] == 'Ford, John ']

# %%
lang = asl[ asl['Director'] == 'Lang, Fritz ']

# %%
thomas =  asl[ asl['Director'] == 'Thomas, Gerald ']

# %%
hitch = asl[ asl['Director'] == 'Hitchcock, Alfred ']

# %%
hitch.groupby('Cinematographer').ASL.mean()
# Out:
# Cinematographer
# Barnes, George              9.00
# Burks, Robert               7.15
# Cooper, Wilkie             10.00
# Courant, Curt               7.50
# Cox, J. & Martin, C.       12.50
# Cox, Jack                   9.70
# Hildyard, Jack              8.50
# Knowles, Bernard            7.50
# Krampf, Gunther            18.00
# MacWilliams, Glen           7.00
# Mat|, Rudolph               7.00
# McDonnell, Claude L.        6.50
# South, Leonard              7.07
# Stradling, Harry            8.15
# Stradling,H.&Knowles        7.00
# Taylor, Gil                 7.00
# Tetzlaff, Ted               8.50
# Valentine & Skall        1000.00
# Valentine, Joseph           7.00
# Ventimiglia                 5.50
# Ventimiglia, Baron          6.00
# Warren, John F.             6.50
# Name: ASL, dtype: float64

# %%
hitch
# Out:
#                                     Title     Alternative Title    Year  \
# 669                    Aventure Malgache                    NaN  1944.0
# 1115                          Birds, The                    NaN  1963.0
# 1181          Blackmail (Silent version)                    NaN  1929.0
# 1182           Blackmail (Sound version)                    NaN  1929.0
# 1301                          Bon Voyage                    NaN  1944.0
# 1814                           Champagne                    NaN  1928.0
# 2713                   Dial M for Murder                    NaN  1954.0
# 2893                            Downhill                    NaN  1927.0
# 3024                         Easy Virtue                    NaN  1928.0
# 3323                         Family Plot                    NaN  1976.0
# 3350                  Farmer's Wife, The                    NaN  1928.0
# 3612               Foreign Correspondent                    NaN  1940.0
# ...

# %%
#displayASL(hitch)
plt.figure(figsize=(20,20))
SMALL_SIZE = 8
MEDIUM_SIZE = 30
BIGGER_SIZE = 12

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.axis([1915,2017,0,44])
plt.grid(True)
plt.plot(hitch['Year'],hitch['ASL'], 'ro',ms=20)
plt.plot(lang['Year'],lang['ASL'], 'b.',ms=20)
plt.plot(ford['Year'],ford['ASL'], 'g*',ms=20)
plt.plot(thomas['Year'],thomas['ASL'], 'm*',ms=18)
plt.xlabel('Years')
plt.ylabel('Average Shot Length (seconds)')
plt.title('ASL of Movies of Hitchcock ')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.grid(True)
hitch[['Year','ASL','Title']].plot('Year','ASL',kind='scatter',ax=plt.gca())

# %%
# compute a cross-tabulation of two Series
directoryear = pd.crosstab(asl.Director, asl.Year)

# %%
directoryear.plot()

# %%
for i in asl.Director.unique():
    print i
# Out:
# Marcks, Greg
# Luketic, Robert
# Snyder, Zack
# Emmerich, Roland
# Brooks, Richard
# Robbins, Matthew
# Plaza, Paco
# Woolcock, Penny
# Edwards, Blake
# Junger, Gil
# Linden, Jamie
# Herek, Stephen
# Kormakur, Baltasar
# Lima, Kevin
# Morresco, Bobby
# Boyle, Danny
# Takashi Miike
# Winick, Gary
# Hathaway, Henry
# Babluani, Gela
# McTiernan, John
# Herzfeld, John
# Donner, Richard
# Steers, Burr
# Capellani, Albert
# Spielberg, Steven
# Chopra, Vidhu Vinod
# Delpy, Julie
# Singleton, John
# Berkowitz, Myles
# Akbari, Mania
# Juran, Nathan
# Fleischer, Richard
# Sullivan, Tim
# Kubrick, Stanley
# Wong Kar Wai
# Dean, Basil
# Inarritu, Alejandro Gonzalez
# Lord, Phil & Miller, Christopher
# Winterbottom, Michael
# Lee, Spike
# Fletcher, Anne
# Thomas, Betty
# Fresnadillo, Juan Carlos
# Cass, Henry
# Turtletaub, Jon
# McNamara, Sean
# Altman, Robert
# Daves, Delmer
# Mangold, James
# Gross, Larry
# Slade, David
# Maté, Rudolph
# Lichtenstein, Demian
# Denis, Claire
# Marchal, Olivier
# ...

# %%
# Out:
# Year
# 14.0      14.100000
# 1075.0     5.940000
# 1911.0    32.000000
# 1912.0    23.875000
# 1913.0    21.628571
# 1914.0    17.552941
# 1915.0    12.233333
# 1916.0    11.050000
# 1917.0     8.896774
# 1918.0    11.814286
# 1919.0     7.347826
# 1920.0     8.060000
# 1921.0     8.875000
# 1922.0     6.310625
# 1923.0     6.364286
# 1924.0     6.263462
# 1925.0     6.217857
# 1926.0     5.691304
# 1927.0     6.046087
# 1928.0     6.005882
# 1929.0     8.407419
# 1930.0    11.192593
# 1931.0    10.787755
# 1932.0     9.676429
# 1933.0     9.503284
# 1934.0    10.137636
# 1935.0     9.409452
# 1936.0     8.399028
# 1937.0     9.041268
# 1938.0     9.324407
#             ...
# 1985.0     6.506146
# 1986.0     7.656196
# 1987.0     6.894924
# 1988.0     6.603566
# 1989.0     7.384307
# 1990.0     6.595468
# 1991.0     7.911087
# 1992.0     6.641145
# 1993.0     6.778434
# 1994.0     6.792548
# 1995.0     6.892274
# 1996.0     6.061837
# 1997.0     5.924985
# 1998.0     5.631439
# ...
